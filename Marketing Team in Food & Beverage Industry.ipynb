# %% [markdown]
# ## Data Analysis Project

# %% [markdown]
# ### Provide Insights to the Marketing Team in Food & Beverage Industry

# %%
import pandas as pd

# %%
df = pd.read_csv('dim_cities.csv')
df1 = pd.read_csv('dim_repondents.csv')
df2 = pd.read_csv('fact_survey_responses.csv')

# %%
df
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %%
df1
# Out:
#       Respondent_ID               Name    Age  Gender City_ID
# 0            120031     Aniruddh Issac  15-18  Female   CT117
# 1            120032        Trisha Rout  19-30    Male   CT118
# 2            120033       Yuvraj  Virk  15-18    Male   CT116
# 3            120034       Pranay Chand  31-45  Female   CT113
# 4            120035     Mohanlal Joshi  19-30  Female   CT120
# ...             ...                ...    ...     ...     ...
# 9995         130026         Arnav Kale  31-45    Male   CT112
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114
# 9998         130029        Jayan Goyal  19-30    Male   CT113
# 9999         130030         Piya Varty  15-18    Male   CT112
#
# [10000 rows x 5 columns]

# %%
df2
# Out:
#       Response_ID  Respondent_ID  Consume_frequency  \
# 0          103001         120031   2-3 times a week
# 1          103002         120032  2-3 times a month
# 2          103003         120033             Rarely
# 3          103004         120034   2-3 times a week
# 4          103005         120035              Daily
# ...           ...            ...                ...
# 9995       112996         130026              Daily
# 9996       112997         130027              Daily
# 9997       112998         130028              Daily
# 9998       112999         130029   2-3 times a week
# 9999       113000         130030              Daily
#
#                          Consume_time                 Consume_reason  \
# 0     To stay awake during work/study     Increased energy and focus
# 1                  Throughout the day           To boost performance
# 2                     Before exercise     Increased energy and focus
# ...

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df2.columns
# Out:
# Index(['Response_ID', 'Respondent_ID', 'Consume_frequency', 'Consume_time',
#        'Consume_reason', 'Heard_before', 'Brand_perception',
#        'General_perception', 'Tried_before', 'Taste_experience',
#        'Reasons_preventing_trying', 'Current_brands',
#        'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df2['Consume_frequency']
# Out:
# 0        2-3 times a week
# 1       2-3 times a month
# 2                  Rarely
# 3        2-3 times a week
# 4                   Daily
#               ...
# 9995                Daily
# 9996                Daily
# 9997                Daily
# 9998     2-3 times a week
# 9999                Daily
# Name: Consume_frequency, Length: 10000, dtype: object

# %%
df.isnull().sum()
# Out:
# City_ID    0
# City       0
# Tier       0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Respondent_ID    0
# Name             0
# Age              0
# Gender           0
# City_ID          0
# dtype: int64

# %%
df1.Gender.unique()
# Out:
# array(['Female', 'Male', 'Non-binary'], dtype=object)

# %%
df2.isnull().sum()
# Out:
# Response_ID                       0
# Respondent_ID                     0
# Consume_frequency                 0
# Consume_time                      0
# Consume_reason                    0
# Heard_before                      0
# Brand_perception                  0
# General_perception                0
# Tried_before                      0
# Taste_experience                  0
# Reasons_preventing_trying         0
# Current_brands                    0
# Reasons_for_choosing_brands       0
# Improvements_desired              0
# Ingredients_expected              0
# Health_concerns                   0
# Interest_in_natural_or_organic    0
# Marketing_channels                0
# Packaging_preference              0
# Limited_edition_packaging         0
# Price_range                       0
# Purchase_location                 0
# Typical_consumption_situations    0
# dtype: int64

# %%
df1.Age.unique()
# Out:
# array(['15-18', '19-30', '31-45', '46-65', '65+'], dtype=object)

# %%
df2.Consume_frequency.unique()
# Out:
# array(['2-3 times a week', '2-3 times a month', 'Rarely', 'Daily',
#        'Once a week'], dtype=object)

# %%
# solving the questions:

# %% [markdown]
# ### Demographic insights:

# %%
filter = df2

# %%
# 1) who prefers energy drink more? 

df1['Gender'].value_counts()
# Out:
# Male          6038
# Female        3455
# Non-binary     507
# Name: Gender, dtype: int64

# %%
# 2) Which Age group prefers energy drinks more?

df1['Age'].value_counts()
# Out:
# 19-30    5520
# 31-45    2376
# 15-18    1488
# 46-65     426
# 65+       190
# Name: Age, dtype: int64

# %%
# 3) Which type of Marketing reaches the most youth(15-30)?

df3 = pd.merge(df1, df2)

# %%
df3
# Out:
#       Respondent_ID               Name    Age  Gender City_ID  Response_ID  \
# 0            120031     Aniruddh Issac  15-18  Female   CT117       103001
# 1            120032        Trisha Rout  19-30    Male   CT118       103002
# 2            120033       Yuvraj  Virk  15-18    Male   CT116       103003
# 3            120034       Pranay Chand  31-45  Female   CT113       103004
# 4            120035     Mohanlal Joshi  19-30  Female   CT120       103005
# ...             ...                ...    ...     ...     ...          ...
# 9995         130026         Arnav Kale  31-45    Male   CT112       112996
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113       112997
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114       112998
# 9998         130029        Jayan Goyal  19-30    Male   CT113       112999
# 9999         130030         Piya Varty  15-18    Male   CT112       113000
#
#       Consume_frequency                     Consume_time  \
# ...

# %%
df3['Age'].unique()
# Out:
# array(['15-18', '19-30', '31-45', '46-65', '65+'], dtype=object)

# %%
df3.dtypes
# Out:
# Respondent_ID                      int64
# Name                              object
# Age                               object
# Gender                            object
# City_ID                           object
# Response_ID                        int64
# Consume_frequency                 object
# Consume_time                      object
# Consume_reason                    object
# Heard_before                      object
# Brand_perception                  object
# General_perception                object
# Tried_before                      object
# Taste_experience                   int64
# Reasons_preventing_trying         object
# Current_brands                    object
# Reasons_for_choosing_brands       object
# Improvements_desired              object
# Ingredients_expected              object
# Health_concerns                   object
# Interest_in_natural_or_organic    object
# Marketing_channels                object
# Packaging_preference              object
# ...

# %%
a = df3[(df3['Age'] == '15-18') | (df3['Age'] == '19-30')]

# %%
a
# Out:
#       Respondent_ID             Name    Age      Gender City_ID  Response_ID  \
# 0            120031   Aniruddh Issac  15-18      Female   CT117       103001
# 1            120032      Trisha Rout  19-30        Male   CT118       103002
# 2            120033     Yuvraj  Virk  15-18        Male   CT116       103003
# 4            120035   Mohanlal Joshi  19-30      Female   CT120       103005
# 5            120036    Zeeshan Ratta  19-30      Female   CT118       103006
# ...             ...              ...    ...         ...     ...          ...
# 9993         130024     Madhav Sheth  19-30  Non-binary   CT113       112994
# 9994         130025     Drishya Kale  19-30        Male   CT112       112995
# 9996         130027  Yuvraj  Agrawal  15-18        Male   CT113       112997
# 9998         130029      Jayan Goyal  19-30        Male   CT113       112999
# 9999         130030       Piya Varty  15-18        Male   CT112       113000
#
# ...

# %%
a.Age.unique()
# Out:
# array(['15-18', '19-30'], dtype=object)

# %%
a['Marketing_channels'].value_counts()
# Out:
# Online ads            3373
# TV commercials        1785
# Other                  702
# Outdoor billboards     702
# Print media            446
# Name: Marketing_channels, dtype: int64

# %% [markdown]
# ### Consumer Preferences:

# %%
# a) What are the preferred ingredients of energy drinks among respondents?

# %%
df3
# Out:
#       Respondent_ID               Name    Age  Gender City_ID  Response_ID  \
# 0            120031     Aniruddh Issac  15-18  Female   CT117       103001
# 1            120032        Trisha Rout  19-30    Male   CT118       103002
# 2            120033       Yuvraj  Virk  15-18    Male   CT116       103003
# 3            120034       Pranay Chand  31-45  Female   CT113       103004
# 4            120035     Mohanlal Joshi  19-30  Female   CT120       103005
# ...             ...                ...    ...     ...     ...          ...
# 9995         130026         Arnav Kale  31-45    Male   CT112       112996
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113       112997
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114       112998
# 9998         130029        Jayan Goyal  19-30    Male   CT113       112999
# 9999         130030         Piya Varty  15-18    Male   CT112       113000
#
#       Consume_frequency                     Consume_time  \
# ...

# %%
df3['Ingredients_expected'].unique()
# Out:
# array(['Guarana', 'Caffeine', 'Vitamins', 'Sugar'], dtype=object)

# %%
df3['Ingredients_expected'].value_counts()
# Out:
# Caffeine    3896
# Vitamins    2534
# Sugar       2017
# Guarana     1553
# Name: Ingredients_expected, dtype: int64

# %%
# b) What packaging preferences do respondents have for energy drinks?

df3['Packaging_preference'].value_counts()
# Out:
# Compact and portable cans    3984
# Innovative bottle design     3047
# Collectible packaging        1501
# Eco-friendly design           983
# Other                         485
# Name: Packaging_preference, dtype: int64

# %% [markdown]
# ### Competition Analysis

# %%
# a) Who are the current market leaders?

df2
# Out:
#       Response_ID  Respondent_ID  Consume_frequency  \
# 0          103001         120031   2-3 times a week
# 1          103002         120032  2-3 times a month
# 2          103003         120033             Rarely
# 3          103004         120034   2-3 times a week
# 4          103005         120035              Daily
# ...           ...            ...                ...
# 9995       112996         130026              Daily
# 9996       112997         130027              Daily
# 9997       112998         130028              Daily
# 9998       112999         130029   2-3 times a week
# 9999       113000         130030              Daily
#
#                          Consume_time                 Consume_reason  \
# 0     To stay awake during work/study     Increased energy and focus
# 1                  Throughout the day           To boost performance
# 2                     Before exercise     Increased energy and focus
# ...

# %%
df2['Current_brands'].value_counts()
# Out:
# Cola-Coka    2538
# Bepsi        2112
# Gangster     1854
# Blue Bull    1058
# CodeX         980
# Sky 9         979
# Others        479
# Name: Current_brands, dtype: int64

# %%
# b) What are the primary reasons consumers prefer those brands over ours?

df2['Current_brands'].unique()
# Out:
# array(['Blue Bull', 'Bepsi', 'Sky 9', 'Cola-Coka', 'Gangster', 'CodeX',
#        'Others'], dtype=object)

# %%
brands = ['Cola-Coka', 'Bepsi', 'Gangster', 'Blue Bull']

# %%
a = df2[df2['Current_brands'].isin(brands)]

# %%
a
# Out:
#       Response_ID  Respondent_ID  Consume_frequency  \
# 1          103002         120032  2-3 times a month
# 2          103003         120033             Rarely
# 3          103004         120034   2-3 times a week
# 5          103006         120036             Rarely
# 6          103007         120037  2-3 times a month
# ...           ...            ...                ...
# 9991       112992         130022   2-3 times a week
# 9992       112993         130023        Once a week
# 9995       112996         130026              Daily
# 9996       112997         130027              Daily
# 9999       113000         130030              Daily
#
#                          Consume_time                 Consume_reason  \
# 1                  Throughout the day           To boost performance
# 2                     Before exercise     Increased energy and focus
# 3     To stay awake during work/study           To boost performance
# ...

# %%
a['Consume_reason'].unique()
# Out:
# array(['To boost performance', 'Increased energy and focus',
#        'To combat fatigue', 'To enhance sports performance', 'Other'],
#       dtype=object)

# %%
a['Reasons_for_choosing_brands'].unique()
# Out:
# array(['Availability', 'Other', 'Brand reputation',
#        'Taste/flavor preference', 'Effectiveness'], dtype=object)

# %% [markdown]
# ### Marketing Channels and Brand Awareness

# %%
# a) Which marketing channel can be used to reach more customers?

# %%
df2.columns
# Out:
# Index(['Response_ID', 'Respondent_ID', 'Consume_frequency', 'Consume_time',
#        'Consume_reason', 'Heard_before', 'Brand_perception',
#        'General_perception', 'Tried_before', 'Taste_experience',
#        'Reasons_preventing_trying', 'Current_brands',
#        'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df2['Marketing_channels'].value_counts()
# Out:
# Online ads            4020
# TV commercials        2688
# Outdoor billboards    1226
# Other                 1225
# Print media            841
# Name: Marketing_channels, dtype: int64

# %%
# b) How effective are different marketing strategies and channels in reaching our customers?

# %% [markdown]
# ### Brand Penetration

# %%
df2['Brand_perception'].unique()
# Out:
# array(['Neutral', 'Positive', 'Negative'], dtype=object)

# %%
# a) What do people think about our brand? (overall rating)
df2['Current_brands' ='CodeX']['Brand_perception'].value_counts()
# Out:
#   File "C:\Users\91968\AppData\Local\Temp/ipykernel_4180/1357979597.py", line 2
#     df2['Current_brands' ='CodeX']['Brand_perception'].value_counts()
#                          ^
# SyntaxError: invalid syntax

# %%
df2[df2['Current_brands'] == 'CodeX']['Brand_perception'].value_counts()
# Out:
# Neutral     589
# Positive    219
# Negative    172
# Name: Brand_perception, dtype: int64

# %%
df2[df2['Current_brands'] == 'CodeX']['Consume_reason'].value_counts()
# Out:
# Increased energy and focus       344
# To combat fatigue                217
# To boost performance             162
# To enhance sports performance    155
# Other                            102
# Name: Consume_reason, dtype: int64

# %%
# b) Which cities do we need to focus more on?

df
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %%
df2['Purchase_location'].unique()
# Out:
# array(['Supermarkets', 'Online retailers', 'Gyms and fitness centers',
#        'Other', 'Local stores'], dtype=object)

# %%
df1
# Out:
#       Respondent_ID               Name    Age  Gender City_ID
# 0            120031     Aniruddh Issac  15-18  Female   CT117
# 1            120032        Trisha Rout  19-30    Male   CT118
# 2            120033       Yuvraj  Virk  15-18    Male   CT116
# 3            120034       Pranay Chand  31-45  Female   CT113
# 4            120035     Mohanlal Joshi  19-30  Female   CT120
# ...             ...                ...    ...     ...     ...
# 9995         130026         Arnav Kale  31-45    Male   CT112
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114
# 9998         130029        Jayan Goyal  19-30    Male   CT113
# 9999         130030         Piya Varty  15-18    Male   CT112
#
# [10000 rows x 5 columns]

# %%
c = pd.merge(df, df1)

# %%
c
# Out:
#      City_ID     City    Tier  Respondent_ID           Name    Age      Gender
# 0      CT111    Delhi  Tier 1         120094   Armaan Bassi  31-45  Non-binary
# 1      CT111    Delhi  Tier 1         120120    Kiaan Uppal  19-30      Female
# 2      CT111    Delhi  Tier 1         120162   Hazel Chanda    65+  Non-binary
# 3      CT111    Delhi  Tier 1         120202     Stuvan Som  19-30      Female
# 4      CT111    Delhi  Tier 1         120217    Adira Raman  31-45      Female
# ...      ...      ...     ...            ...            ...    ...         ...
# 9995   CT120  Lucknow  Tier 2         129719  Aaryahi Wason  19-30      Female
# 9996   CT120  Lucknow  Tier 2         129777   Ryan Kothari  15-18        Male
# 9997   CT120  Lucknow  Tier 2         129814   Sara Kothari  19-30        Male
# 9998   CT120  Lucknow  Tier 2         129829    Shamik Deep  19-30      Female
# 9999   CT120  Lucknow  Tier 2         130001    Ahana  Arya  19-30        Male
#
# ...

# %%
c['City'].value_counts()
# Out:
# Bangalore    2828
# Hyderabad    1833
# Mumbai       1510
# Chennai       937
# Pune          906
# Kolkata       566
# Ahmedabad     456
# Delhi         429
# Jaipur        360
# Lucknow       175
# Name: City, dtype: int64

# %%
df
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %% [markdown]
# ### Purchase Behavior

# %%
# a) Where do respondents prefer to purchase energy drinks from?

df2.columns
# Out:
# Index(['Response_ID', 'Respondent_ID', 'Consume_frequency', 'Consume_time',
#        'Consume_reason', 'Heard_before', 'Brand_perception',
#        'General_perception', 'Tried_before', 'Taste_experience',
#        'Reasons_preventing_trying', 'Current_brands',
#        'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df2['Purchase_location'].value_counts()
# Out:
# Supermarkets                4494
# Online retailers            2550
# Gyms and fitness centers    1464
# Local stores                 813
# Other                        679
# Name: Purchase_location, dtype: int64

# %%
# b) What are the typical consumption situations for energy drinks among respondents?

df2['Typical_consumption_situations'].value_counts()
# Out:
# Sports/exercise           4494
# Studying/working late     3231
# Social outings/parties    1487
# Other                      491
# Driving/commuting          297
# Name: Typical_consumption_situations, dtype: int64

# %%
# c) What factors influence respondents' purchase decisions, such as price range and limited edition packaging?
df2['Price_range'].value_counts()
# Out:
# 50-99        4288
# 100-150      3142
# Above 150    1561
# Below 50     1009
# Name: Price_range, dtype: int64

# %%
df2['Limited_edition_packaging'].value_counts()
# Out:
# No          4023
# Yes         3946
# Not Sure    2031
# Name: Limited_edition_packaging, dtype: int64

# %% [markdown]
# ### Product Development

# %%
# a) Which area of business should we focus more on our product development? (Branding/taste/availability)

# imo: different areas, different solutions.

# %%
df2.columns
# Out:
# Index(['Response_ID', 'Respondent_ID', 'Consume_frequency', 'Consume_time',
#        'Consume_reason', 'Heard_before', 'Brand_perception',
#        'General_perception', 'Tried_before', 'Taste_experience',
#        'Reasons_preventing_trying', 'Current_brands',
#        'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Respondent_ID', 'Name', 'Age', 'Gender', 'City_ID', 'Response_ID',
#        'Consume_frequency', 'Consume_time', 'Consume_reason', 'Heard_before',
#        'Brand_perception', 'General_perception', 'Tried_before',
#        'Taste_experience', 'Reasons_preventing_trying', 'Current_brands',
#        'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %%
df4 = pd.merge(df,df3)

# %%
df4.columns
# Out:
# Index(['City_ID', 'City', 'Tier', 'Respondent_ID', 'Name', 'Age', 'Gender',
#        'Response_ID', 'Consume_frequency', 'Consume_time', 'Consume_reason',
#        'Heard_before', 'Brand_perception', 'General_perception',
#        'Tried_before', 'Taste_experience', 'Reasons_preventing_trying',
#        'Current_brands', 'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %%
df4[df4['Tier'] == 'Tier 1']['Consume_frequency'].value_counts()
# Out:
# 2-3 times a week     2743
# Rarely               1389
# 2-3 times a month    1256
# Daily                1081
# Once a week          1068
# Name: Consume_frequency, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 2']['Consume_frequency'].value_counts()
# Out:
# 2-3 times a week     748
# Rarely               552
# Once a week          541
# 2-3 times a month    357
# Daily                265
# Name: Consume_frequency, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 1']['Consume_reason'].value_counts()
# Out:
# Increased energy and focus       2673
# To combat fatigue                1826
# To enhance sports performance    1279
# To boost performance             1080
# Other                             679
# Name: Consume_reason, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 2']['Consume_reason'].value_counts()
# Out:
# Increased energy and focus       901
# To combat fatigue                602
# To boost performance             434
# To enhance sports performance    325
# Other                            201
# Name: Consume_reason, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 1']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           1962
# Availability               1486
# Taste/flavor preference    1452
# Other                      1357
# Effectiveness              1280
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 2']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           690
# Taste/flavor preference    559
# Effectiveness              468
# Availability               424
# Other                      322
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 2']['Price_range'].value_counts()
# Out:
# 50-99        1075
# 100-150       768
# Above 150     371
# Below 50      249
# Name: Price_range, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 1']['Price_range'].value_counts()
# Out:
# 50-99        3213
# 100-150      2374
# Above 150    1190
# Below 50      760
# Name: Price_range, dtype: int64

# %%
Typical_consumption_situations

# %%
df4[df4['Tier'] == 'Tier 1']['Typical_consumption_situations'].value_counts()
# Out:
# Sports/exercise           3399
# Studying/working late     2433
# Social outings/parties    1106
# Other                      380
# Driving/commuting          219
# Name: Typical_consumption_situations, dtype: int64

# %%
df4[df4['Tier'] == 'Tier 2']['Typical_consumption_situations'].value_counts()
# Out:
# Sports/exercise           1095
# Studying/working late      798
# Social outings/parties     381
# Other                      111
# Driving/commuting           78
# Name: Typical_consumption_situations, dtype: int64

# %%
df4['Current_brands'].unique()
# Out:
# array(['Blue Bull', 'Others', 'Gangster', 'Cola-Coka', 'Sky 9', 'CodeX',
#        'Bepsi'], dtype=object)

# %%
df4['Current_brands'].value_counts()
# Out:
# Cola-Coka    2538
# Bepsi        2112
# Gangster     1854
# Blue Bull    1058
# CodeX         980
# Sky 9         979
# Others        479
# Name: Current_brands, dtype: int64

# %%
df4[df4['Current_brands'] == 'Cola-Coka']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           616
# Taste/flavor preference    531
# Availability               510
# Other                      448
# Effectiveness              433
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Current_brands'] == 'Bepsi']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           577
# Taste/flavor preference    423
# Availability               418
# Other                      355
# Effectiveness              339
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Current_brands'] == 'Gangster']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           511
# Taste/flavor preference    357
# Availability               339
# Effectiveness              338
# Other                      309
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Current_brands'] == 'Blue Bull']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           289
# Taste/flavor preference    237
# Effectiveness              187
# Availability               180
# Other                      165
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4[df4['Current_brands'] == 'CodeX']['Reasons_for_choosing_brands'].value_counts()
# Out:
# Brand reputation           259
# Availability               195
# Taste/flavor preference    182
# Effectiveness              176
# Other                      168
# Name: Reasons_for_choosing_brands, dtype: int64

# %%
df4['Taste_experience']
# Out:
# 0       2
# 1       5
# 2       1
# 3       5
# 4       3
#        ..
# 9995    1
# 9996    3
# 9997    5
# 9998    4
# 9999    4
# Name: Taste_experience, Length: 10000, dtype: int64

# %%
df4[df4['Current_brands'] == 'CodeX']['Taste_experience'].value_counts()
# Out:
# 3    286
# 4    248
# 5    191
# 2    148
# 1    107
# Name: Taste_experience, dtype: int64

# %%
df4[df4['Current_brands'] == 'Cola-Coka']['Taste_experience'].value_counts()
# Out:
# 3    756
# 4    632
# 5    518
# 2    362
# 1    270
# Name: Taste_experience, dtype: int64

# %%
Improvements_desired

# %%
df4[df4['Current_brands'] == 'CodeX']['Improvements_desired'].value_counts()
# Out:
# Reduced sugar content       298
# More natural ingredients    234
# Wider range of flavors      208
# Healthier alternatives      143
# Other                        97
# Name: Improvements_desired, dtype: int64

# %%
df4[df4['Current_brands'] == 'Cola-Coka']['Improvements_desired'].value_counts()
# Out:
# Reduced sugar content       742
# More natural ingredients    645
# Wider range of flavors      500
# Healthier alternatives      394
# Other                       257
# Name: Improvements_desired, dtype: int64

# %%
df4[df4['Current_brands']]['Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4180/3019148065.py in <module>
# ----> 1 df4[df4['Current_brands']]['Age']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df4.loc[df4['Current_brands'] == 'CodeX', 'Age'].value_counts()
# Out:
# 19-30    540
# 31-45    242
# 15-18    135
# 46-65     37
# 65+       26
# Name: Age, dtype: int64

# %%
df4.loc[df4['Current_brands'] == 'Cola-Coka', 'Age'].value_counts()
# Out:
# 19-30    1450
# 31-45     615
# 15-18     313
# 46-65     114
# 65+        46
# Name: Age, dtype: int64

# %%
df4.columns
# Out:
# Index(['City_ID', 'City', 'Tier', 'Respondent_ID', 'Name', 'Age', 'Gender',
#        'Response_ID', 'Consume_frequency', 'Consume_time', 'Consume_reason',
#        'Heard_before', 'Brand_perception', 'General_perception',
#        'Tried_before', 'Taste_experience', 'Reasons_preventing_trying',
#        'Current_brands', 'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')
